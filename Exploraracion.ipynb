# %% [markdown]
# Dataset datathon 2025
# - Exploraracion de los datos
# - Actulizacion modelo

# %%
import pandas as pd

diatomeas = pd.read_csv("01_DiatomInventories_GTstudentproject_B.csv")
sitios = pd.read_csv("02_InfoSites_GTstudentproject_B.csv")
test = pd.read_csv("03_IBD_GTstudentproject_test.csv")
train = pd.read_csv("03_IBD_GTstudentproject_train.csv")

# %%
diatomeas.head()
# Out:
#                    TaxonName TaxonCode SamplingOperations_code  \
# 0  Achnanthes aapajaervensis   Achaa01      S04094200_20120910
# 1  Achnanthes aapajaervensis   Achaa01      S05155300_20100728
# 2         Achnanthes affinis   Achaf01      S02018780_20070808
# 3         Achnanthes affinis   Achaf01      S02022675_20090803
# 4         Achnanthes affinis   Achaf01      S02094920_20120726
#
#   CodeSite_SamplingOperations Date_SamplingOperation  Abundance_nbcell  \
# 0                   S04094200             2012-09-10                 8
# 1                   S05155300             2010-07-28                 1
# 2                   S02018780             2007-08-08                 1
# 3                   S02022675             2009-08-03                 2
# 4                   S02094920             2012-07-26                 1
#
#    TotalAbundance_SamplingOperation  Abundance_pm
# 0                               420     19.047619
# 1                               404      2.475248
# 2                               400      2.500000
# 3                               400      5.000000
# 4                               400      2.500000

# %%
sitios.head()
# Out:
#   CodeSite_SamplingOperations  Longitude_Lambert93  Latitude_Lambert93  \
# 0                   S02096750             993887.0           6875414.0
# 1                   S05170800             596306.0           6214010.0
# 2                   S05201050             371740.0           6264090.0
# 3                   S02067400             984385.0           6837446.0
# 4                   S05023100             488324.0           6553060.0
#
#        Watershed CodeDepartement  HERlvl1Code          HERlvl1Name  \
# 0     Rhin-Meuse              67           10  COTES CALCAIRES EST
# 1  Adour-Garonne              09           14    COTEAUX AQUITAINS
# 2  Adour-Garonne              64           14    COTEAUX AQUITAINS
# 3     Rhin-Meuse              54           10  COTES CALCAIRES EST
# 4  Adour-Garonne              16            9     TABLES CALCAIRES
#
#    HERlvl2Code                            HERlvl2Name  Altitude Streamsize
# 0           25                        Plateau lorrain     225.0        NaN
# 1           68      Coteaux molassiques Est Aquitaine     424.0         TP
# 2           77  Coteaux molassiques bassin de l'adour      25.0          P
# 3           25                        Plateau lorrain     260.0          M
# 4           97                  TC - Charentes Poitou      99.0         TP

# %%
train.head()
# Out:
#   SamplingOperations_code  IBD   IBD_EQR IBD_EQR_Status
# 0      S04319000_20130724  5.2  0.256098            Bad
# 1      S06172100_20080716  6.1  0.298246            Bad
# 2      S03255920_20120802  3.7  0.157895            Bad
# 3      S04064720_20150710  4.9  0.228070            Bad
# 4      S05001500_20080726  5.3  0.251462            Bad

# %%
import seaborn as sb

# %%
sb.countplot(
    x="IBD_EQR_Status",
    data=train
)
# Out:
# <Axes: xlabel='IBD_EQR_Status', ylabel='count'>

# %%
train["IBD_EQR_Status"].value_counts()
# Out:
# IBD_EQR_Status
# Good        17061
# Moderate    14396
# High         9637
# Poor         2383
# Bad           306
# Name: count, dtype: int64

# %%
diatomeas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1643872 entries, 0 to 1643871
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   TaxonName                         1643872 non-null  object
#  1   TaxonCode                         1643872 non-null  object
#  2   SamplingOperations_code           1643872 non-null  object
#  3   CodeSite_SamplingOperations       1643872 non-null  object
#  4   Date_SamplingOperation            1643872 non-null  object
#  5   Abundance_nbcell                  1643872 non-null  int64
#  6   TotalAbundance_SamplingOperation  1643872 non-null  int64
#  7   Abundance_pm                      1643872 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 100.3+ MB

# %%
diatomeas.hist(figsize=(15,8), bins=30,)
# Out:
# array([[<Axes: title={'center': 'Abundance_nbcell'}>,
#         <Axes: title={'center': 'TotalAbundance_SamplingOperation'}>],
#        [<Axes: title={'center': 'Abundance_pm'}>, <Axes: >]], dtype=object)

# %%
sitios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8404 entries, 0 to 8403
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CodeSite_SamplingOperations  8404 non-null   object
#  1   Longitude_Lambert93          8404 non-null   float64
#  2   Latitude_Lambert93           8404 non-null   float64
#  3   Watershed                    8404 non-null   object
#  4   CodeDepartement              8404 non-null   object
#  5   HERlvl1Code                  8404 non-null   int64
#  6   HERlvl1Name                  8404 non-null   object
#  7   HERlvl2Code                  8404 non-null   int64
#  8   HERlvl2Name                  8404 non-null   object
#  9   Altitude                     8404 non-null   float64
#  10  Streamsize                   8291 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 722.3+ KB

# %%
sitios.hist(figsize=(15,8), bins=30,)
# Out:
# array([[<Axes: title={'center': 'Longitude_Lambert93'}>,
#         <Axes: title={'center': 'Latitude_Lambert93'}>],
#        [<Axes: title={'center': 'HERlvl1Code'}>,
#         <Axes: title={'center': 'HERlvl2Code'}>],
#        [<Axes: title={'center': 'Altitude'}>, <Axes: >]], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 8))
sb.scatterplot(
    x="Longitude_Lambert93",
    y="Latitude_Lambert93",
    data=sitios,
    hue="Streamsize",
    size="Altitude",  
    sizes=(50, 200)   
)
# Out:
# <Axes: xlabel='Longitude_Lambert93', ylabel='Latitude_Lambert93'>

# %%
features = pd.merge(
    sitios, 
    diatomeas, 
    on="CodeSite_SamplingOperations", 
    how="inner"
)

# %%
datasetFa= pd.merge(
    features, 
    train, 
    on="SamplingOperations_code", 
    how="inner" 
)

# %%
datasetFa.head()
# Out:
#   CodeSite_SamplingOperations  Longitude_Lambert93  Latitude_Lambert93  \
# 0                   S02096750             993887.0           6875414.0
# 1                   S02096750             993887.0           6875414.0
# 2                   S02096750             993887.0           6875414.0
# 3                   S02096750             993887.0           6875414.0
# 4                   S02096750             993887.0           6875414.0
#
#     Watershed CodeDepartement  HERlvl1Code          HERlvl1Name  HERlvl2Code  \
# 0  Rhin-Meuse              67           10  COTES CALCAIRES EST           25
# 1  Rhin-Meuse              67           10  COTES CALCAIRES EST           25
# 2  Rhin-Meuse              67           10  COTES CALCAIRES EST           25
# 3  Rhin-Meuse              67           10  COTES CALCAIRES EST           25
# 4  Rhin-Meuse              67           10  COTES CALCAIRES EST           25
#
#        HERlvl2Name  Altitude  ...              TaxonName TaxonCode  \
# 0  Plateau lorrain     225.0  ...   Achnanthes conspicua   Achco02
# 1  Plateau lorrain     225.0  ...  Achnanthes eutrophila   Acheu01
# 2  Plateau lorrain     225.0  ...  Achnanthes eutrophila   Acheu01
# 3  Plateau lorrain     225.0  ...  Achnanthes eutrophila   Acheu01
# 4  Plateau lorrain     225.0  ...  Achnanthes eutrophila   Acheu01
#
#   SamplingOperations_code Date_SamplingOperation Abundance_nbcell  \
# 0      S02096750_20150813             2015-08-13                4
# 1      S02096750_20070829             2007-08-29               68
# 2      S02096750_20080805             2008-08-05               22
# 3      S02096750_20090701             2009-07-01               16
# 4      S02096750_20100903             2010-09-03               17
#
#    TotalAbundance_SamplingOperation  Abundance_pm   IBD   IBD_EQR  \
# 0                               403      9.925558  14.3  0.777778
# 1                               400    170.000000  14.8  0.807018
# 2                               400     55.000000  13.5  0.730994
# 3                               400     40.000000  15.1  0.824561
# 4                               400     42.500000  14.3  0.777778
#
#    IBD_EQR_Status
# 0        Moderate
# 1            Good
# 2        Moderate
# 3            Good
# 4        Moderate
#
# [5 rows x 21 columns]
